# %% [markdown]
# <a href="https://colab.research.google.com/github/TRohit20/Python-Lab-Playground/blob/main/Google_Search_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16127 sha256=89a19a12b3c42ed5d17c093719d80e6fde04c86bc994f0a793037aeb0bc00b79
#   Stored in directory: /root/.cache/pip/wheels/e8/78/c8/18d4f4804753e14416809b365773220c48b41fe5387f2bb6b9
# Successfully built pytrends
# ...

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Machine Learning"])
data = trends.interest_by_region()
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#             Machine Learning
# geoName
# China                    100
# Singapore                 45
# Ethiopia                  44
# St. Helena                34
# India                     32
# Tunisia                   26
# Hong Kong                 24
# Pakistan                  24
# Nepal                     21
# Sri Lanka                 21

# %%
data.reset_index().plot(x="geoName", y="Machine Learning", figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Devops'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Devops'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Devops', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
